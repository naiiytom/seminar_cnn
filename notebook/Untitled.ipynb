# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use('ggplot')

# %%
train_loss_wo = [1.081902084515449891e+00,
8.258494305695202042e-01,
7.656393825796479202e-01,
7.188991651678762196e-01,
6.622256033175381029e-01,
5.951579791222904037e-01,
5.454351600814373313e-01,
5.026660999613450365e-01,
4.753876512354992534e-01,
4.198454138657725654e-01
]
    
train_loss_w = [1.239675150272694149e+00,
9.971659960264854794e-01,
9.129876688862523793e-01,
8.266584293005314610e-01,
7.756239303671721430e-01,
7.294271840905466320e-01,
6.931838377887475922e-01,
6.545450963238452768e-01,
6.346678733825683594e-01,
6.017026629642392432e-01
]

# %%
val_loss_wo = [8.129466064274311066e-01,
8.509423471987247467e-01,
8.780735060572624207e-01,
7.243785560131072998e-01,
6.690945141017436981e-01,
6.416097469627857208e-01,
6.196340192109346390e-01,
6.251309383660554886e-01,
5.922457780689001083e-01,
5.827185325324535370e-01
]
val_loss_w = [1.067145939916372299e+00,
9.314696788787841797e-01,
8.738031275570392609e-01,
8.257730342447757721e-01,
8.034328147768974304e-01,
7.260586135089397430e-01,
6.706085987389087677e-01,
7.021510619670152664e-01,
6.662622541189193726e-01,
6.106642987579107285e-01
]

# %%
plt.figure(figsize=(16,9))
plt.plot(train_loss_wo, color='r', linestyle='-', label='training loss')
plt.plot(train_loss_w, color='r', linestyle='--', label = 'training loss + augmentation')
plt.plot(val_loss_wo, color='b', linestyle='-', label='validation loss')
plt.plot(val_loss_w, color='b', linestyle='--', label='validation loss + augmentation')
plt.title('VGG Net11 Loss')
plt.legend()
plt.savefig('./output/vgg_loss.png', dpi=300)
plt.show()
